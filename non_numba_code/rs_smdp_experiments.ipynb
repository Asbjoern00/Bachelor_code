# %%
import experiment_utils as utils
import pandas as pd
subdir = "rs_smdp"
test = pd.read_pickle(f"experiment_results/{subdir}/nS_8_unif.pkl")
test = test[[#"UCRL_SMDP, T_max = 2", "UCRL_SMDP, T_max = 3", "UCRL_SMDP, T_max = 4", "UCRL_SMDP, T_max = 5", "UCRL_SMDP, T_max = 6"]]
             "UCRL_SMDP-L, T_max = 2", "UCRL_SMDP-L, T_max = 3", "UCRL_SMDP-L, T_max = 4", "UCRL_SMDP-L, T_max = 5", "UCRL_SMDP-L, T_max = 6"]]

# %%
utils.plot_mean_regret_from_pd(test, nS =8)
# Out:
# /home/asr/.local/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/asr/.local/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
