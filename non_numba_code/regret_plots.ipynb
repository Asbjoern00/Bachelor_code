# %%
import pandas as pd
import numpy as np
import riverswim_class as rs 
import riverswim_class_smdp as rs_s
import UCRL2_L as ucrl
import UCRL_SMDP as ucrlS
import experiment_utils as utils
import importlib
importlib.reload(rs)
importlib.reload(rs_s)
importlib.reload(ucrl)
importlib.reload(utils)
import matplotlib.pyplot as plt

# %%
nS5 = pd.read_pickle("C:/Users/andre/Downloads/nS_5.pkl")
nS5
# Out:
#          UCRL_SMDP, T_max = 2  UCRL_SMDP, T_max = 3  UCRL_SMDP, T_max = 4  \
# 0                    0.693834              0.675084              0.856355
# 1                    1.095967              1.058467              1.245988
# 2                    1.498099              1.564780              1.641870
# 3                    1.952322              1.954412              2.146114
# 4                    2.464885              2.337795              2.483656
# ...                       ...                   ...                   ...
# 4999995          54959.879535          64886.921215          71952.162897
# 4999996          54959.796237          64887.004619          71952.354662
# 4999997          54959.812981          64886.921321          71952.321385
# 4999998          54959.788023          64887.004724          71952.321385
# 4999999          54959.688086          64886.854766          71952.279788
#
#          UCRL_SMDP, T_max = 5  UCRL_SMDP, T_max = 6  UCRL_SMDP-L, T_max = 2  \
# 0                    0.416723              1.510599                0.681334
# 1                    0.833446              1.621030                0.895946
# 2                    1.560620              2.314864                1.466849
# 3                    1.996093              2.366954                1.798141
# 4                    2.256545              2.710747                2.479476
# ...                       ...                   ...                     ...
# 4999995          78329.029578         110036.546256             4896.754514
# 4999996          78329.254620         110036.813000             4896.904577
# 4999997          78329.146364         110036.496445             4897.304641
# 4999998          78329.163107         110036.496445             4897.338023
# 4999999          78329.271469         110036.454849             4897.304746
#
#          UCRL_SMDP-L, T_max = 3  UCRL_SMDP-L, T_max = 4  \
# 0                      0.681334                0.604244
# 1                      1.070967                1.150147
# 2                      1.571030                2.019003
# 3                      1.837732                2.246114
# 4                      2.396135                2.639927
# ...                         ...                     ...
# 4999995             9239.771195            14764.029598
# 4999996             9239.804577            14764.137960
# 4999997             9239.621342            14764.163023
# 4999998             9239.596384            14764.079725
# 4999999             9239.638086            14764.179767
#
#          UCRL_SMDP-L, T_max = 5  UCRL_SMDP-L, T_max = 6  UCRL2, T_max = 1
# 0                      0.675084                1.025126          0.435473
# 1                      1.058467                1.458530          0.870946
# 2                      1.746051                1.925253          1.312668
# 3                      2.069024                2.100274          1.754391
# 4                      2.692018                2.792039          2.189864
# ...                         ...                     ...               ...
# 4999995            19491.829620            29257.496279      51837.221173
# 4999996            19491.754641            29257.888022      51837.312896
# 4999997            19491.338044            29257.346426      51837.404619
# 4999998            19491.321406            29257.404766      51837.871342
# 4999999            19490.979788            29257.429829      51837.838065
#
# [5000000 rows x 11 columns]

# %%
# 5 State plot. 
utils.plot_mean_regret_from_pd(nS5,5)
# Out:
# C:\Users\andre\AppData\Roaming\Python\Python310\site-packages\IPython\core\events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\andre\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
