# %%
import pandas as pd
import numpy as np
import riverswim_class as rs 
import riverswim_class_smdp as rs_s
import UCRL2_L as ucrl
import UCRL_SMDP as ucrlS
import experiment_utils as utils
import importlib
importlib.reload(rs)
importlib.reload(rs_s)
importlib.reload(ucrl)
importlib.reload(utils)
import matplotlib.pyplot as plt

# %% [markdown]
# We Start off by plotting UCRL-SMDP and UCRL-SMDP.
# This is done for Riverswim (the option version).
# Note all paths are only for local saving purposes.

# %%
# We read data.
nS5_ucrl_l = pd.read_pickle("C:/Users/andre/Downloads/nS_5_ucrl_l.pkl")
nS5_ucrl = pd.read_pickle("C:/Users/andre/Downloads/nS_5_correct_confidence.pkl")

#nS10_ucrl = pd.read_pickle("C:/Users/andre/Downloads/nS_10_correct_confidence.pkl")
#nS15_ucrl = pd.read_pickle("C:/Users/andre/Downloads/nS_15_correct_confidence.pkl")
#nS20_ucrl = pd.read_pickle("C:/Users/andre/Downloads/nS_20_correct_confidence.pkl")
#nS25_ucrl = pd.read_pickle("C:/Users/andre/Downloads/nS_25_correct_confidence.pkl")
#nS30_ucrl = pd.read_pickle("C:/Users/andre/Downloads/nS_30_correct_confidence.pkl")


fruit = nS5_ucrl[['UCRL_SMDP, T_max = 2','UCRL_SMDP, T_max = 3','UCRL_SMDP, T_max = 4','UCRL_SMDP, T_max = 5','UCRL2, T_max = 1']]
us = nS5_ucrl[['UCRL_SMDP-L, T_max = 2','UCRL_SMDP-L, T_max = 3','UCRL_SMDP-L, T_max = 4','UCRL_SMDP-L, T_max = 5']]
us= pd.concat([us, nS5_ucrl_l], axis=1)
us.rename({'UCRL2_L, T_max = 1': 'UCRL2-L, T_max = 1'}, axis=1, inplace=True)

us
# Out:
#          UCRL_SMDP-L, T_max = 2  UCRL_SMDP-L, T_max = 3  \
# 0                      0.686757                1.070135
# 1                      1.020135                1.070135
# 2                      1.363513                1.516858
# 3                      1.726891                1.880236
# 4                      2.340303                2.303648
# ...                         ...                     ...
# 4999995              424.564107             2152.234141
# 4999996              424.110863             2152.100863
# 4999997              423.897552             2151.887552
# 4999998              423.750964             2152.220998
# 4999999              423.937654             2152.007687
#
#          UCRL_SMDP-L, T_max = 4  UCRL_SMDP-L, T_max = 5  UCRL2-L, T_max = 1
# 0                      1.026790                0.986790            0.446723
# 1                      1.306824                1.640202            0.893447
# 2                      1.763547                2.013580            1.330170
# 3                      2.460303                2.480303            1.766894
# 4                      2.887026                2.623681            2.223617
# ...                         ...                     ...                 ...
# 4999995             1737.984174             2931.580863         1562.742042
# 4999996             1738.064208             2931.754242         1563.208765
# 4999997             1738.437586             2931.834275         1563.475488
# 4999998             1738.517620             2932.300998         1563.142212
# 4999999             1738.771032             2932.341099         1563.208935
#
# [5000000 rows x 5 columns]

# %% [markdown]
# Below are various plots of SMDPUCRL in the riverswim environment.

# %%
for i in [5,10,15,20,25,30]:    
    # We read data.
    data_l = pd.read_pickle("C:/Users/andre/Downloads/nS_"+str(i)+"_ucrl_l.pkl")
    data = pd.read_pickle("C:/Users/andre/Downloads/nS_"+str(i)+"_correct_confidence.pkl")


    if i ==5:
        fruit = data[['UCRL_SMDP, T_max = 2','UCRL_SMDP, T_max = 3','UCRL_SMDP, T_max = 4','UCRL_SMDP, T_max = 5','UCRL2, T_max = 1']]
        us = data[['UCRL_SMDP-L, T_max = 2','UCRL_SMDP-L, T_max = 3','UCRL_SMDP-L, T_max = 4','UCRL_SMDP-L, T_max = 5']]
    if i ==10:
        fruit = data[['UCRL_SMDP, T_max = 2','UCRL_SMDP, T_max = 4','UCRL_SMDP, T_max = 6','UCRL_SMDP, T_max = 8','UCRL_SMDP, T_max = 10','UCRL2, T_max = 1']]
        us = data[['UCRL_SMDP-L, T_max = 2','UCRL_SMDP-L, T_max = 4','UCRL_SMDP-L, T_max = 6','UCRL_SMDP-L, T_max = 8','UCRL_SMDP-L, T_max = 10']]
    if i ==15:
        fruit = data[['UCRL_SMDP, T_max = 2','UCRL_SMDP, T_max = 5','UCRL_SMDP, T_max = 8','UCRL_SMDP, T_max = 11','UCRL_SMDP, T_max = 14','UCRL2, T_max = 1']]
        us = data[['UCRL_SMDP-L, T_max = 2','UCRL_SMDP-L, T_max = 5','UCRL_SMDP-L, T_max = 8','UCRL_SMDP-L, T_max = 11','UCRL_SMDP-L, T_max = 14']]
    if i ==20:
        fruit = data[['UCRL_SMDP, T_max = 2','UCRL_SMDP, T_max = 6','UCRL_SMDP, T_max = 10','UCRL_SMDP, T_max = 14','UCRL_SMDP, T_max = 18','UCRL2, T_max = 1']]
        us = data[['UCRL_SMDP-L, T_max = 2','UCRL_SMDP-L, T_max = 6','UCRL_SMDP-L, T_max = 10','UCRL_SMDP-L, T_max = 14','UCRL_SMDP-L, T_max = 18']]  
    if i == 25:    
        fruit = data[['UCRL_SMDP, T_max = 2','UCRL_SMDP, T_max = 7','UCRL_SMDP, T_max = 12','UCRL_SMDP, T_max = 17','UCRL_SMDP, T_max = 22','UCRL2, T_max = 1']]
        us = data[['UCRL_SMDP-L, T_max = 2','UCRL_SMDP-L, T_max = 7','UCRL_SMDP-L, T_max = 12','UCRL_SMDP-L, T_max = 17','UCRL_SMDP-L, T_max = 22']]
    if i ==30:
        fruit = data[['UCRL_SMDP, T_max = 2','UCRL_SMDP, T_max = 8','UCRL_SMDP, T_max = 14','UCRL_SMDP, T_max = 20','UCRL_SMDP, T_max = 26','UCRL2, T_max = 1']]
        us = data[['UCRL_SMDP-L, T_max = 2','UCRL_SMDP-L, T_max = 8','UCRL_SMDP-L, T_max = 14','UCRL_SMDP-L, T_max = 20','UCRL_SMDP-L, T_max = 26']]
    
    
    us= pd.concat([us, data_l], axis=1)
    us.rename({'UCRL2_L, T_max = 1': 'UCRL2-L, T_max = 1'}, axis=1, inplace=True)

    # plots
    utils.plot_mean_regret_from_pd(fruit,i)
    plt.legend(framealpha=0.05,loc='center', bbox_to_anchor=(0.5, -0.25), ncol=3,prop={'size': 8})
    plt.tight_layout()
    plt.savefig('C:/Users/andre/OneDrive/KU, MAT-OEK/Bachelor matematik-oekonomi/3. aar/Bachelorprojekt/Out/nS'+str(i)+'_ucrl.png')
    plt.show()
    utils.plot_mean_regret_from_pd(us,i)
    plt.legend(framealpha=0.05,loc='center', bbox_to_anchor=(0.5, -0.25), ncol=3,prop={'size': 8})
    plt.tight_layout()
    plt.savefig('C:/Users/andre/OneDrive/KU, MAT-OEK/Bachelor matematik-oekonomi/3. aar/Bachelorprojekt/Out/nS'+str(i)+'_ucrl_l.png')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\andre\Bachelor_code\regret_plots.ipynb Cell 5 in 3
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Bachelor_code/regret_plots.ipynb#W4sZmlsZQ%3D%3D?line=27'>28</a> us.rename({'UCRL2_L, T_max = 1': 'UCRL2-L, T_max = 1'}, axis=1, inplace=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Bachelor_code/regret_plots.ipynb#W4sZmlsZQ%3D%3D?line=29'>30</a> # plots
# ---> <a href='vscode-notebook-cell:/c%3A/Users/andre/Bachelor_code/regret_plots.ipynb#W4sZmlsZQ%3D%3D?line=30'>31</a> utils.plot_mean_regret_from_pd(fruit,i)
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Bachelor_code/regret_plots.ipynb#W4sZmlsZQ%3D%3D?line=31'>32</a> plt.legend(framealpha=0.05,loc='center', bbox_to_anchor=(0.5, -0.25), ncol=3,prop={'size': 8})
#      <a href='vscode-notebook-cell:/c%3A/Users/andre/Bachelor_code/regret_plots.ipynb#W4sZmlsZQ%3D%3D?line=32'>33</a> plt.tight_layout()
#
# File c:\Users\andre\Bachelor_code\experiment_utils.py:209, in plot_mean_regret_from_pd(df, nS)
#     207 def plot_mean_regret_from_pd(df, nS):
#     208     for col in df.columns:
# --> 209         plt.plot(df[col].values, label = col)
#     210     plt.legend()
#     211     plt.xlabel("T")
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2728, in plot(scalex, scaley, data, *args, **kwargs)
#    2726 @_copy_docstring_and_deprecators(Axes.plot)
#    2727 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2728     return gca().plot(
#    2729         *args, scalex=scalex, scaley=scaley,
#    2730         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2225, in gca()
#    2223 @_copy_docstring_and_deprecators(Figure.gca)
#    2224 def gca():
# -> 2225     return gcf().gca()
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\figure.py:1615, in FigureBase.gca(self)
#    1605 """
#    1606 Get the current Axes.
#    1607
#    (...)
#    1612 whether `.pyplot.get_fignums()` is empty.)
#    1613 """
#    1614 ax = self._axstack.current()
# -> 1615 return ax if ax is not None else self.add_subplot()
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\figure.py:745, in FigureBase.add_subplot(self, *args, **kwargs)
#     742         args = tuple(map(int, str(args[0])))
#     743     projection_class, pkw = self._process_projection_requirements(
#     744         *args, **kwargs)
# --> 745     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     746     key = (projection_class, pkw)
#     747 return self._add_axes_internal(ax, key)
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_subplots.py:34, in SubplotBase.__init__(self, fig, *args, **kwargs)
#      15 """
#      16 Parameters
#      17 ----------
#    (...)
#      31     Keyword arguments are passed to the Axes (sub)class constructor.
#      32 """
#      33 # _axes_class is set in the subplot_class_factory
# ---> 34 self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35 # This will also update the axes position.
#      36 self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:645, in _AxesBase.__init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     642 self.spines = mspines.Spines.from_dict(self._gen_axes_spines())
#     644 # this call may differ for non-sep axes, e.g., polar
# --> 645 self._init_axis()
#     646 if facecolor is None:
#     647     facecolor = mpl.rcParams['axes.facecolor']
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:777, in _AxesBase._init_axis(self)
#     775 def _init_axis(self):
#     776     # This is moved out of __init__ because non-separable axes don't use it
# --> 777     self.xaxis = maxis.XAxis(self)
#     778     self.spines.bottom.register_axis(self.xaxis)
#     779     self.spines.top.register_axis(self.xaxis)
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axis.py:2193, in XAxis.__init__(self, *args, **kwargs)
#    2190 super().__init__(*args, **kwargs)
#    2191 # x in axes coords, y in display coords (to be updated at draw time by
#    2192 # _update_label_positions and _update_offset_text_position).
# -> 2193 self.label.set(
#    2194     x=0.5, y=0,
#    2195     verticalalignment='top', horizontalalignment='center',
#    2196     transform=mtransforms.blended_transform_factory(
#    2197         self.axes.transAxes, mtransforms.IdentityTransform()),
#    2198 )
#    2199 self.label_position = 'bottom'
#    2200 self.offsetText.set(
#    2201     x=1, y=0,
#    2202     verticalalignment='top', horizontalalignment='right',
#    (...)
#    2206     color=mpl.rcParams['xtick.color'],
#    2207 )
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py:117, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     109 if not hasattr(cls.set, '_autogenerated_signature'):
#     110     # Don't overwrite cls.set if the subclass or one of its parents
#     111     # has defined a set method set itself.
#     112     # If there was no explicit definition, cls.set is inherited from
#     113     # the hierarchy of auto-generated set methods, which hold the
#     114     # flag _autogenerated_signature.
#     115     return
# --> 117 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     118 cls.set.__name__ = "set"
#     119 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py:1194, in Artist.set(self, **kwargs)
#    1190 def set(self, **kwargs):
#    1191     # docstring and signature are auto-generated via
#    1192     # Artist._update_set_signature_and_docstring() at the end of the
#    1193     # module.
# -> 1194     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py:1186, in Artist._internal_update(self, kwargs)
#    1179 def _internal_update(self, kwargs):
#    1180     """
#    1181     Update artist properties without prenormalizing them, but generating
#    1182     errors as if calling `set`.
#    1183
#    1184     The lack of prenormalization is to maintain backcompatibility.
#    1185     """
# -> 1186     return self._update_props(
#    1187         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1188         "{prop_name!r}")
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\artist.py:1151, in Artist._update_props(self, props, errfmt)
#    1144 """
#    1145 Helper for `.Artist.set` and `.Artist.update`.
#    1146
#    1147 *errfmt* is used to generate error messages for invalid property
#    1148 names; it get formatted with ``type(self)`` and the property name.
#    1149 """
#    1150 ret = []
# -> 1151 with cbook._setattr_cm(self, eventson=False):
#    1152     for k, v in props.items():
#    1153         # Allow attributes we want to be able to update through
#    1154         # art.update, art.set, setp.
#    1155         if k == "axes":
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\andre\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\cbook\__init__.py:2051, in _setattr_cm(obj, **kwargs)
#    2049 try:
#    2050     for attr, val in kwargs.items():
# -> 2051         setattr(obj, attr, val)
#    2052     yield
#    2053 finally:
#
# KeyboardInterrupt:

# %% [markdown]
# We now try Both algorithm on the SMDP version of riverswim.

# %%
# We read data.
binom = pd.read_pickle("C:/Users/andre/Downloads/nS_8_bin.pkl")
unif = pd.read_pickle("C:/Users/andre/Downloads/nS_8_unif.pkl")

# Generate T_max data (i.e. create data with the similar ones in one)


binom
# Out:
#          UCRL_SMDP, T_max = 2  UCRL_SMDP, T_max = 3  UCRL_SMDP, T_max = 4  \
# 0                    0.412516              0.310987              0.337015
# 1                    0.495645              0.384650              0.368864
# 2                    0.888160              0.458312              0.400712
# 3                    1.032854              0.828407              0.624031
# 4                    1.383805              0.956624              0.795501
# ...                       ...                   ...                   ...
# 2999995         288730.019781         344991.834721         293338.505056
# 2999996         288730.329167         344991.903830         293338.584678
# 2999997         288730.535425         344991.987588         293338.664299
# 2999998         288730.644812         344991.987588         293338.743920
# 2999999         288730.851070         344992.091250         293338.823542
#
#          UCRL_SMDP, T_max = 5  UCRL_SMDP, T_max = 6  UCRL_SMDP, T_max = 7  \
# 0                    0.228137              0.172830              0.222208
# 1                    0.260356              0.201961              0.236649
# 2                    0.292575              0.231093              0.251091
# 3                    0.324794              0.356640              0.364415
# 4                    0.543671              0.378489              0.374043
# ...                       ...                   ...                   ...
# 2999995         239647.570294         179471.701683         143095.501408
# 2999996         239647.623992         179471.805380         143095.679174
# 2999997         239647.677691         179471.995493         143095.679174
# 2999998         239647.731389         179472.099190         143095.708801
# 2999999         239647.785088         179472.116473         143095.886567
#
#          UCRL_SMDP, T_max = 8  UCRL_SMDP-L, T_max = 2  UCRL_SMDP-L, T_max = 3  \
# 0                    0.233315                0.257822                0.380095
# 1                    0.242201                0.465645                0.404650
# 2                    0.251087                0.673467                0.636528
# 3                    0.523289                0.942854                0.868407
# 4                    0.523289                1.109112                0.892962
# ...                       ...                     ...                     ...
# 2999995         115649.538213            10675.511344            17429.600168
# 2999996         115649.551175            10675.717602            17429.711155
# 2999997         115649.641909            10675.375424            17429.918480
# 2999998         115649.654871            10675.284811            17429.918480
# 2999999         115649.745605            10675.291069            17430.029467
#
#          UCRL_SMDP-L, T_max = 4  UCRL_SMDP-L, T_max = 5  \
# 0                      0.233318                0.331835
# 1                      0.281091                0.353315
# 2                      0.328864                0.374794
# 3                      0.619955                0.582191
# 4                      0.651804                0.665150
# ...                         ...                     ...
# 2999995            23027.600603            28993.713994
# 2999996            23027.807997            28993.807693
# 2999997            23027.711694            28993.922131
# 2999998            23027.815391            28993.940268
# 2999999            23027.667240            28993.951007
#
#          UCRL_SMDP-L, T_max = 6  UCRL_SMDP-L, T_max = 7  \
# 0                      0.311093                0.207394
# 1                      0.325659                0.221835
# 2                      0.340225                0.236277
# 3                      0.513054                0.433671
# 4                      0.513054                0.438484
# ...                         ...                     ...
# 2999995            46083.248971            42459.466968
# 2999996            46083.342669            42459.570293
# 2999997            46083.349952            42459.584734
# 2999998            46083.347347            42459.599176
# 2999999            46083.241045            42459.613617
#
#          UCRL_SMDP-L, T_max = 8
# 0                      0.246277
# 1                      0.255163
# 2                      0.264049
# 3                      0.272935
# 4                      0.281821
# ...                         ...
# 2999995            48805.854870
# 2999996            48805.854870
# 2999997            48805.854870
# 2999998            48805.854870
# 2999999            48805.958566
#
# [3000000 rows x 14 columns]

# %%
# Generate T_max data (i.e. create data with the similar ones in one)

for i in range(2,9):    
    b_data = binom[['UCRL_SMDP, T_max = '+str(i)]]
    b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, binomial, T_max = '+str(i)}, axis=1, inplace=True)

    b_data= pd.concat([b_data, unif[['UCRL_SMDP, T_max = '+str(i)]]], axis=1)
    b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, uniform, T_max = '+str(i)}, axis=1, inplace=True)

    bl_data = binom[['UCRL_SMDP-L, T_max = '+str(i)]]
    bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, binomial, T_max = '+str(i)}, axis=1, inplace=True)

    bl_data= pd.concat([bl_data, unif[['UCRL_SMDP-L, T_max = '+str(i)]]], axis=1)
    bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, uniform, T_max = '+str(i)}, axis=1, inplace=True)

    # plots
    utils.plot_mean_regret_from_pd(b_data,8)
    plt.legend(framealpha=0.05,loc='center', bbox_to_anchor=(0.5, -0.25), ncol=2,prop={'size': 8})
    plt.tight_layout()
    plt.savefig('C:/Users/andre/OneDrive/KU, MAT-OEK/Bachelor matematik-oekonomi/3. aar/Bachelorprojekt/Out/distr_Tmax'+str(i)+'_nS8.png')
    plt.show()
    utils.plot_mean_regret_from_pd(bl_data,8)
    plt.legend(framealpha=0.05,loc='center', bbox_to_anchor=(0.5, -0.25), ncol=2,prop={'size': 8})
    plt.tight_layout()
    plt.savefig('C:/Users/andre/OneDrive/KU, MAT-OEK/Bachelor matematik-oekonomi/3. aar/Bachelorprojekt/Out/distr_Tmax'+str(i)+'_nS8_L.png')
    plt.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b_data.rename({'UCRL_SMDP, T_max = '+str(i): 'UCRL_SMDP, binomial, T_max = '+str(i)}, axis=1, inplace=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_20336\913701583.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bl_data.rename({'UCRL_SMDP-L, T_max = '+str(i): 'UCRL_SMDP-L, binomial, T_max = '+str(i)}, axis=1, inplace=True)
