# %% [markdown]
# Plotting of SMDP-EXP3

# %%
import numpy as np

import importlib


import matplotlib.pyplot as plt
import gc
import pandas as pd

# %% [markdown]
# nS = 10:

# %%
#######
## Do the plotting. 

smdpexp10_9 = pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/smdpexp3_rs/smpdexp3_ns_10_Tmax_9_N4.pkl")
smdpexp10_10 = pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/smdpexp3_rs/smpdexp3_ns_10_Tmax_10_N4.pkl")
smdpexp10_11 = pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/smdpexp3_rs/smpdexp3_ns_10_Tmax_11_N4.pkl")
bus10 = pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/bus_opt_rs/bus_ns_10_opt_H_100")
smdpucrl_l =  pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/rs_ucrl_l/nS_10_correct_confidence.pkl")
smdpucrl_l10 = smdpucrl_l['UCRL_SMDP-L, T_max = 10']

# %%
plt.plot(smdpexp10_9,label='SMDP-EXP3, T_max = 9')
plt.plot(smdpexp10_10,label='SMDP-EXP3, T_max = 10')
plt.plot(smdpexp10_11,label='SMDP-EXP3, T_max = 11')
#plt.plot(bus10,label='BUS, H = 100')
#plt.plot(smdpucrl_l10,label='SMDP-UCRL, T_max = 10')

plt.legend()
plt.show()

# %% [markdown]
# nS = 20

# %%
#######
## Do the plotting. 

smdpexp20_19 = pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/smdpexp3_rs/smpdexp3_ns_20_Tmax_19_N4.pkl")
smdpexp20_20 = pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/smdpexp3_rs/smpdexp3_ns_20_Tmax_20_N4.pkl")
smdpexp20_21 = pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/smdpexp3_rs/smpdexp3_ns_20_Tmax_21_N4.pkl")
bus20 = pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/bus_opt_rs/bus_ns_20_opt_H_100")
smdpucrl_l =  pd.read_pickle("C:/Users/andre/Bachelor_code/experiment_results/rs_ucrl_l/nS_20_correct_confidence.pkl")
smdpucrl_l20 = smdpucrl_l['UCRL_SMDP-L, T_max = 20']

# %%
plt.plot(smdpexp20_19,label='SMDP-EXP3, T_max = 19')
plt.plot(smdpexp20_20,label='SMDP-EXP3, T_max = 20')
plt.plot(smdpexp20_21,label='SMDP-EXP3, T_max = 21')
#plt.plot(bus20,label='BUS, H = 100')
#plt.plot(smdpucrl_l20,label='SMDP-UCRL, T_max = 20')

plt.legend()
plt.show()
